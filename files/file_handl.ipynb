# %%
file = open('india.txt','w')
file.write('Animesh \n')
file.write('Sam \n')
file.close()

# %%
file = open('india.txt','a')
file.write('india \n')
file.write('india \n')
file.write('india \n')
file.write('india \n')
file.write('india \n')
file.write('india \n')
file.close()
