# %%
import os
if os.path.exists("India-.txt"):
    print('File exists')
else:
    file = open('India-.txt','w')
    file.write('India won semifinal 2 \n')
    file.write('India won semifinal 2 \n')
    file.write('India won semifinal 2 \n')
    file.close()

# %%
with open('India-.txt','r') as f:
    data = f.read()
    print(data)
# Out:
# India won semifinal 2
# India won semifinal 2
# India won semifinal 2

# %%
with open('India-.txt','a') as f:
    f.write('Jaaaaa \n')
    f.write('Jaaaaa \n')
    f.write('Jaaaaa \n')
    f.write('Jaaaaa \n')

# %%
file = open('India-.txt', 'r')
line = file.readline()

while line:
    print(line.strip())  
    line = file.readline()  

file.close()
# Out:
# India won semifinal 2
# India won semifinal 2
# India won semifinal 2
# Jaaaaa
# Jaaaaa
# Jaaaaa
# Jaaaaa

# %%
try:
    file = open('aaaaaaaaaaaaaaaaaaaaaaaa.txt','r')
    print(file)
except FileNotFoundError as f:
    print('FIle doesnot exist')
# Out:
# FIle doesnot exist
