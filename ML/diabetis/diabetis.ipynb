# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', palette='Dark2') 
from mlxtend.plotting import plot_decision_regions

# %%
data=pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
data.columns=['pregnancies' , 'glucose' ,'bloodPressure' ,'skinThickness' , 'Insulin' ,'bmi' , 'dpFunction' ,'age' , 'outcome']

# %%
data
# Out:
#      pregnancies  glucose  bloodPressure  ...  dpFunction  age  outcome
# 0              6      148             72  ...       0.627   50        1
# 1              1       85             66  ...       0.351   31        0
# 2              8      183             64  ...       0.672   32        1
# 3              1       89             66  ...       0.167   21        0
# 4              0      137             40  ...       2.288   33        1
# ..           ...      ...            ...  ...         ...  ...      ...
# 763           10      101             76  ...       0.171   63        0
# 764            2      122             70  ...       0.340   27        0
# 765            5      121             72  ...       0.245   30        0
# 766            1      126             60  ...       0.349   47        1
# 767            1       93             70  ...       0.315   23        0
#
# [768 rows x 9 columns]

# %%
sns.countplot(x=data['pregnancies'][data.outcome==1] , hue=data.outcome)
# Out:
# <Axes: xlabel='pregnancies', ylabel='count'>

# %%
sns.distplot(x=data.bmi)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_1096\4033416817.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.bmi)
# <Axes: ylabel='Density'>

# %%
sns.lineplot(x=data.age , y=data.glucose)
# Out:
# <Axes: xlabel='age', ylabel='glucose'>

# %%
sns.distplot(x=data.age)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_1096\2176378535.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.age)
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data=data.corr() , annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=data.glucose , y=data.Insulin , hue=data.outcome)
# Out:
# <Axes: xlabel='glucose', ylabel='Insulin'>

# %%
data
# Out:
#      pregnancies  glucose  bloodPressure  ...  dpFunction  age  outcome
# 0              6      148             72  ...       0.627   50        1
# 1              1       85             66  ...       0.351   31        0
# 2              8      183             64  ...       0.672   32        1
# 3              1       89             66  ...       0.167   21        0
# 4              0      137             40  ...       2.288   33        1
# ..           ...      ...            ...  ...         ...  ...      ...
# 763           10      101             76  ...       0.171   63        0
# 764            2      122             70  ...       0.340   27        0
# 765            5      121             72  ...       0.245   30        0
# 766            1      126             60  ...       0.349   47        1
# 767            1       93             70  ...       0.315   23        0
#
# [768 rows x 9 columns]

# %%
sns.countplot(x=data['pregnancies'][data.outcome==1])
# Out:
# <Axes: xlabel='pregnancies', ylabel='count'>

# %%
sns.scatterplot(x=data.glucose , y=data.glucose , hue=data.outcome)
# Out:
# <Axes: xlabel='glucose', ylabel='glucose'>

# %%
sns.scatterplot(x=data.Insulin , y=data.Insulin , hue=data.outcome)
# Out:
# <Axes: xlabel='Insulin', ylabel='Insulin'>

# %%
sns.scatterplot(x=data.glucose , y=data.glucose , hue=data.outcome)
# Out:
# <Axes: xlabel='glucose', ylabel='glucose'>

# %%
sns.scatterplot(x=data.bloodPressure , y=data.bloodPressure , hue=data.outcome)
# Out:
# <Axes: xlabel='bloodPressure', ylabel='bloodPressure'>

# %%
sns.scatterplot(x=data.bmi , y=data.bmi , hue=data.outcome)
# Out:
# <Axes: xlabel='bmi', ylabel='bmi'>

# %%
for i in data:
    print(data[i].unique())
    print()
# Out:
# [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]
#
# [148  85 183  89 137 116  78 115 197 125 110 168 139 189 166 100 118 107
#  103 126  99 196 119 143 147  97 145 117 109 158  88  92 122 138 102  90
#  111 180 133 106 171 159 146  71 105 101 176 150  73 187  84  44 141 114
#   95 129  79   0  62 131 112 113  74  83 136  80 123  81 134 142 144  93
#  163 151  96 155  76 160 124 162 132 120 173 170 128 108 154  57 156 153
#  188 152 104  87  75 179 130 194 181 135 184 140 177 164  91 165  86 193
#  191 161 167  77 182 157 178  61  98 127  82  72 172  94 175 195  68 186
#  198 121  67 174 199  56 169 149  65 190]
#
# [ 72  66  64  40  74  50   0  70  96  92  80  60  84  30  88  90  94  76
#   82  75  58  78  68 110  56  62  85  86  48  44  65 108  55 122  54  52
#   98 104  95  46 102 100  61  24  38 106 114]
#
# [35 29  0 23 32 45 19 47 38 30 41 33 26 15 36 11 31 37 42 25 18 24 39 27
#  21 34 10 60 13 20 22 28 54 40 51 56 14 17 50 44 12 46 16  7 52 43 48  8
#  49 63 99]
#
# ...

# %%
inputs = data.drop(['outcome','skinThickness'] , axis=1)
output=data.outcome

# %%
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import ColumnTransformer
# ct=ColumnTransformer([('pregnancies' , OneHotEncoder() , [0])] , remainder='passthrough')
# inputs=np.array(ct.fit_transform(inputs) , dtype=str)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(inputs , output , test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression().fit(x_train , y_train)
yp=lg.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test , yp))
# Out:
# [[49  8]
#  [ 6 14]]

# %%
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp))
print(precision_score(y_test , yp))
print(recall_score(y_test , yp))
print(f1_score(y_test , yp))
# Out:
# 0.8181818181818182
# 0.6363636363636364
# 0.7
# 0.6666666666666666

# %%
from sklearn.neighbors import KNeighborsClassifier
alg=KNeighborsClassifier(n_neighbors=5)
alg.fit(x_train,y_train)
yp=alg.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp))
print(precision_score(y_test , yp))
print(recall_score(y_test , yp))
print(f1_score(y_test , yp))
# Out:
# 0.8051948051948052
# 0.6190476190476191
# 0.65
# 0.6341463414634146

# %% [markdown]
# # naive baised algo is used here for more improvement in the model

# %%
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(x_train , y_train)
# Out:
# GaussianNB()

# %%
yp1=clf.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.7662337662337663
# 0.5416666666666666
# 0.65
# 0.5909090909090909

# %%
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(x_train ,y_train)
yp1 = model.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.7662337662337663
# 0.5384615384615384
# 0.7
# 0.6086956521739131

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
alg = DecisionTreeClassifier(criterion='entropy')
alg.fit(x_train , y_train)
yp1 = alg.predict(x_test)
print(accuracy_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(f1_score(y_test , yp1))

# plt.figure(figsize=(20,20))
# plot_tree(alg)
# plt.show()
# Out:
# 0.7012987012987013
# 0.45454545454545453
# 0.75
# 0.5660377358490566

# %% [markdown]
# # using svm support vector machine

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train , y_train)
yp1 = model.predict(x_test)
print(accuracy_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(f1_score(y_test , yp1))

print(model.score(x_train , y_train))
print(model.score(x_test , y_test))
# Out:
# 0.8311688311688312
# 0.6666666666666666
# 0.7
# 0.6829268292682927
# 0.7756874095513748
# 0.8311688311688312
