# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\anime\Downloads\auto+mpg\auto-mpg.data", delim_whitespace=True , header=None)
data
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
data.columns=['mpg','cylinders','displacement','horsepower','weight','acceleration','modelyear','origin','carname']
data
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# modelyear       0
# origin          0
# carname         0
# dtype: int64

# %%
data['mpg'].dtype
# Out:
# dtype('float64')

# %%
print(data.horsepower.unique())
data.horsepower.replace('?','0')
# data.horsepower.astype(float)
# Out:
# ['130.0' '165.0' '150.0' '140.0' '198.0' '220.0' '215.0' '225.0' '190.0'
#  '170.0' '160.0' '95.00' '97.00' '85.00' '88.00' '46.00' '87.00' '90.00'
#  '113.0' '200.0' '210.0' '193.0' '?' '100.0' '105.0' '175.0' '153.0'
#  '180.0' '110.0' '72.00' '86.00' '70.00' '76.00' '65.00' '69.00' '60.00'
#  '80.00' '54.00' '208.0' '155.0' '112.0' '92.00' '145.0' '137.0' '158.0'
#  '167.0' '94.00' '107.0' '230.0' '49.00' '75.00' '91.00' '122.0' '67.00'
#  '83.00' '78.00' '52.00' '61.00' '93.00' '148.0' '129.0' '96.00' '71.00'
#  '98.00' '115.0' '53.00' '81.00' '79.00' '120.0' '152.0' '102.0' '108.0'
#  '68.00' '58.00' '149.0' '89.00' '63.00' '48.00' '66.00' '139.0' '103.0'
#  '125.0' '133.0' '138.0' '135.0' '142.0' '77.00' '62.00' '132.0' '84.00'
#  '64.00' '74.00' '116.0' '82.00']
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393    86.00
# 394    52.00
# 395    84.00
# 396    79.00
# 397    82.00
# Name: horsepower, Length: 398, dtype: object

# %%
data1=data.describe(include='all')
data1
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration   modelyear      origin     carname
# count     398.000000  398.000000  398.000000         398
# ...

# %%
data.replace(['?'],data1['horsepower'][2],inplace=True)

# %%
data['horsepower'].dtype
# Out:
# dtype('O')

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# modelyear         int64
# origin            int64
# carname          object
# dtype: object

# %%
data['horsepower'].unique()
data['horsepower'].dtype
data['horsepower']=data['horsepower'].astype(float)
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# modelyear         int64
# origin            int64
# carname          object
# dtype: object

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin                    carname
# 0           70       1  chevrolet chevelle malibu
# ...

# %%
# data=data.drop(['carname'],axis=1)
data2=data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', palette='Dark2')

# %%
sns.lineplot(x=data.mpg ,y=data.displacement)
# Out:
# <Axes: xlabel='mpg', ylabel='displacement'>

# %%
sns.lineplot(x=data.displacement , y=data.horsepower)
# Out:
# <Axes: xlabel='displacement', ylabel='horsepower'>

# %%
sns.scatterplot(x=data.mpg , y=data.horsepower , hue=data.cylinders)
# Out:
# <Axes: xlabel='mpg', ylabel='horsepower'>

# %%
sns.boxplot(x=data.cylinders , y=data.horsepower)
# Out:
# <Axes: xlabel='cylinders', ylabel='horsepower'>

# %%
sns.lineplot(x=data.weight , y=data.horsepower )
# Out:
# <Axes: xlabel='weight', ylabel='horsepower'>

# %%
sns.boxenplot(x=data.modelyear , y=data.horsepower)
# Out:
# <Axes: xlabel='modelyear', ylabel='horsepower'>

# %%
sns.lineplot(x=data.weight , y=data.acceleration)
# Out:
# <Axes: xlabel='weight', ylabel='acceleration'>

# %%
# sns.distplot(x=data.acceleration)
sns.distplot(x=data.horsepower)
# Out:
# <Axes: ylabel='Density'>

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin                    carname
# 0           70       1  chevrolet chevelle malibu
# ...

# %%
# data=data.drop(['carname'] ,axis=1)
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin                    carname
# 0           70       1  chevrolet chevelle malibu
# ...

# %%
sns.boxenplot(x=data.origin , y=data.horsepower)
# Out:
# <Axes: xlabel='origin', ylabel='horsepower'>

# %%
sns.scatterplot(x=data.displacement , y=data.acceleration , hue=data.origin)
# Out:
# <Axes: xlabel='displacement', ylabel='acceleration'>

# %%
sns.boxplot(x=data.cylinders , y=data.mpg)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
sns.boxplot(x=data.cylinders , y=data.mpg)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
sns.lineplot(x=data.weight , y=data.mpg)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sns.lineplot(x=data.acceleration , y=data.mpg)
# Out:
# <Axes: xlabel='acceleration', ylabel='mpg'>

# %%
sns.lineplot(x=data.acceleration , y=data.mpg)
# Out:
# <Axes: xlabel='acceleration', ylabel='mpg'>

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin                    carname
# 0           70       1  chevrolet chevelle malibu
# ...

# %%
data.drop(['carname'] , inplace=True , axis=1)

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin
# 0           70       1
# 1           70       1
# 2           70       1
# 3           70       1
# ...

# %% [markdown]
# ## i was wrong bcs i thought hp is out put
# # But output is {    mpg    }

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  105.155779  2970.424623
# std      7.815984    1.701004    104.269838   38.600986   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  130.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration   modelyear      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
sns.scatterplot(x=data.displacement , y=data.mpg ,hue=data.origin)
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %%
sns.scatterplot(x=data.acceleration , y=data.mpg ,hue=data.origin)
# Out:
# <Axes: xlabel='acceleration', ylabel='mpg'>

# %%
sns.scatterplot(x=data.weight , y=data.mpg ,hue=data.origin)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr() , annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x=data.cylinders , y=data.mpg , hue=data.cylinders)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# # taking mpg as output and removing from the main dataset

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin
# 0           70       1
# 1           70       1
# 2           70       1
# 3           70       1
# ...

# %%
ip=data.drop(['mpg'],axis=1)
op=data['mpg']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.84788416, -0.84680776, -1.09442082, ..., -0.31113688,
#          1.63761601, -0.70641209],
#        [ 1.4915573 ,  1.1822101 ,  1.12361867, ..., -0.3834896 ,
#         -0.26232182, -0.70641209],
#        [ 0.32183657,  0.53444853,  0.1038304 , ...,  0.23150848,
#          0.00909787, -0.70641209],
#        ...,
#        [-0.84788416, -0.9134891 , -1.17090495, ...,  2.36591357,
#          0.00909787, -0.70641209],
#        [ 1.4915573 ,  1.48703908,  1.50603928, ..., -1.28789854,
#         -1.34800059, -0.70641209],
#        [ 1.4915573 ,  1.96333435,  3.16319522, ..., -2.19230747,
#         -0.80516121, -0.70641209]])

# %%
x_test
# Out:
# array([[ 0.31311215,  0.4445941 ,  0.05630715, -0.15086557, -0.24043506,
#         -0.90739287, -0.79584062],
#        [ 0.31311215,  0.63168221,  0.21718472,  0.58678663, -0.42827494,
#         -0.1067521 , -0.79584062],
#        [ 1.56556073,  1.67106059,  0.21718472,  1.07332318,  1.26228404,
#          1.22764918, -0.79584062],
#        [-0.93933644, -0.34533347, -0.20109696, -0.37189965, -0.46584292,
#          1.22764918, -0.79584062],
#        [-0.93933644, -1.05211077, -0.71590518, -1.0977808 , -0.42827494,
#         -1.44115338,  0.38318252],
#        [ 0.31311215,  0.37183762, -0.26544799,  0.62340766,  1.14958011,
#          0.96076892, -0.79584062],
#        [-0.93933644, -1.02092942, -1.0054848 , -1.22857019,  0.02254079,
#          1.49452944,  1.56220566],
#        [ 0.31311215,  0.11199302, -0.42632555,  0.21665263,  0.39822056,
#          0.42700841, -0.79584062],
#        [-0.93933644, -0.88581023, -0.10457042, -0.69233367,  0.69876438,
# ...

# %%
from sklearn.linear_model import LinearRegression
alg=LinearRegression().fit(x_train , y_train)
alg
# Out:
# LinearRegression()

# %%
yp=alg.predict(x_test)

# %%
yp
# Out:
# array([21.6155138 , 19.83396505, 22.57910621, 28.20670896, 24.7731544 ,
#        22.66231935, 35.43098467, 22.85580661, 21.95535898, 10.98573588,
#        25.20155303, 11.88498889, 34.52826016, 29.48807333, 30.37647232,
#        26.04420766, 28.30417221, 14.86413554, 24.73162466, 29.26866574,
#        30.61014758,  9.61802116, 25.4588188 , 30.94396846, 14.96502154,
#        15.74937941, 18.21010412, 18.75131655, 30.47253805, 21.92854395,
#        22.66745331, 17.97768599,  9.14319801, 36.26145778, 23.19596099,
#        30.82280131, 31.24278233, 20.16705322, 23.32248877, 19.77195961])

# %%
new_df=pd.DataFrame({
    'y':list(y_test),
    'pred':yp
})

# %%
new_df
# Out:
#        y       pred
# 0   18.0  21.615514
# 1   22.0  19.833965
# 2   26.6  22.579106
# 3   25.8  28.206709
# 4   30.0  24.773154
# 5   19.1  22.662319
# 6   32.0  35.430985
# 7   20.8  22.855807
# 8   25.0  21.955359
# 9   13.0  10.985736
# 10  28.0  25.201553
# 11  16.0  11.884989
# 12  34.1  34.528260
# 13  28.0  29.488073
# 14  32.1  30.376472
# 15  32.7  26.044208
# 16  27.0  28.304172
# 17  16.0  14.864136
# 18  30.7  24.731625
# 19  32.0  29.268666
# 20  32.0  30.610148
# 21  14.0   9.618021
# 22  24.0  25.458819
# 23  35.7  30.943968
# 24  13.0  14.965022
# 25  13.0  15.749379
# 26  19.0  18.210104
# 27  15.0  18.751317
# 28  29.0  30.472538
# 29  18.1  21.928544
# 30  17.6  22.667453
# 31  18.0  17.977686
# 32  14.0   9.143198
# 33  39.1  36.261458
# 34  24.0  23.195961
# 35  43.4  30.822801
# 36  41.5  31.242782
# 37  13.0  20.167053
# 38  23.0  23.322489
# 39  18.5  19.771960

# %%
x=np.array([10,307,130,3540,0,12,34]).reshape(1,-1)
sc.fit(x)
x=sc.transform(x)
alg.predict(x)
# Out:
# array([23.42178771])

# %%
from sklearn.metrics import mean_squared_error , r2_score
mse=mean_squared_error(y_test , yp)
print(mse)
r2=r2_score(y_test , yp)
print(r2)
# Out:
# 17.321124721412406
# 0.7499854797269735

# %%
for i in data:
    print('\n',i)
    print(data[i].unique())

print(data.dtypes)
# Out:
#  mpg
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
#  cylinders
# [8 4 6 3 5]
#
#  displacement
# [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x_train=poly.fit_transform(x_train)
x_test = poly.fit_transform(x_test)
alg.fit(x_train,y_train)
pred_y = alg.predict(x_test)






from sklearn.metrics import mean_squared_error , r2_score
print(mean_squared_error(pred_y , y_test))
print(r2_score(pred_y , y_test))
# Out:
# 13.813969847628783
# 0.7563066842563102
