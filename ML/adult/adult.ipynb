# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', palette='Dark2')

# %%
data=pd.read_csv('adult.csv')
data.columns=(['age','workclass' ,'fnlwgt' , 'education' , 'educational_num' , 'marital_status' , 'occupation' ,'relationship' ,'race' ,'gender' ,'capital_gain' ,'capital_loss' ,'hours_per_week', 'native_country' ,'income' ])

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational_num    0
# marital_status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital_gain       0
# capital_loss       0
# hours_per_week     0
# native_country     0
# income             0
# dtype: int64

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational_num     int64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital_gain        int64
# capital_loss        int64
# hours_per_week      int64
# native_country     object
# income             object
# dtype: object

# %%
for i in data:
    print(i,'\n')
    print(data[i].unique())
    print('\n\n')
# Out:
# age
#
# [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87 86]
#
#
#
# workclass
#
# ['Private' 'Local-gov' '?' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
#
#
# fnlwgt
#
# [226802  89814 336951 ... 129912 255835 257302]
#
#
#
# education
#
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
#
#
# educational_num
#
# [ 7  9 12 10  6 15  4 13 14 16  3 11  5  8  2  1]
#
#
#
# marital_status
#
# ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
#
#
# occupation
#
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' '?'
# ...

# %%
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational_num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital_status      occupation relationship   race gender  \
# ...

# %%
d=data.describe(include='all')
data.workclass.replace('?' , d['workclass'][2] , inplace=True)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\1809508743.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.workclass.replace('?' , d['workclass'][2] , inplace=True)
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\1809508743.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
data.occupation.replace('?' , d['occupation'][2] , inplace=True)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\1336912601.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.occupation.replace('?' , d['occupation'][2] , inplace=True)
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\1336912601.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.native_country.replace('?' , d['native_country'][2] , inplace=True)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\2344788630.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.native_country.replace('?' , d['native_country'][2] , inplace=True)
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\2344788630.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
for i in data:
    print(data[i].unique())
    print('\n\n')
# Out:
# [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87 86]
#
#
#
# ['Private' 'Local-gov' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
#
#
# [226802  89814 336951 ... 129912 255835 257302]
#
#
#
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
#
#
# [ 7  9 12 10  6 15  4 13 14 16  3 11  5  8  2  1]
#
#
#
# ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
#
#
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' 'Prof-specialty'
#  'Other-service' 'Craft-repair' 'Adm-clerical' 'Exec-managerial'
#  'Tech-support' 'Sales' 'Priv-house-serv' 'Transport-moving'
# ...

# %%
d=data.describe(include='all')
d
# Out:
#                  age workclass        fnlwgt education  educational_num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         8           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     36705           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital_status      occupation relationship   race gender  \
# ...

# %%
data.isnull().sum(0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational_num    0
# marital_status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital_gain       0
# capital_loss       0
# hours_per_week     0
# native_country     0
# income             0
# dtype: int64

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
sns.countplot(x=data.workclass , hue=data.income)
# Out:
# <Axes: xlabel='workclass', ylabel='count'>

# %%
sns.distplot(x=data[data.income==1].age , color='red')
sns.distplot(x=data[data.income==0].age , color='blue')
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\593647219.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data[data.income==1].age , color='red')
# c:\Users\anime\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\593647219.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
plt.Figure(figsize=(12,10))
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
sns.countplot(x=data.education , hue=data.income)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.lineplot(x=data.hours_per_week ,y=data.hours_per_week, hue=data.income)
# Out:
# <Axes: xlabel='hours_per_week', ylabel='hours_per_week'>

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
sns.countplot(x=data.race , hue=data.income)
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
plt.xticks(rotation=90 , ha='left')
sns.countplot(x=data.educational_num , hue=data.income)
# Out:
# <Axes: xlabel='educational_num', ylabel='count'>

# %%
sns.countplot(x=data.gender , hue=data.income)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.xticks(rotation=90 , ha='left')
sns.countplot(x=data.marital_status , hue=data.income)
# Out:
# <Axes: xlabel='marital_status', ylabel='count'>

# %%
plt.xticks(rotation=90 , ha='left')
sns.countplot(x=data.occupation , hue=data.income)
# Out:
# <Axes: xlabel='occupation', ylabel='count'>

# %%
plt.xticks(rotation=90 , ha='left')
sns.countplot(x=data.relationship , hue=data.income)
# Out:
# <Axes: xlabel='relationship', ylabel='count'>

# %%
sns.distplot(x=data[data.income==1].capital_gain , color='red')
sns.distplot(x=data[data.income==0].capital_gain , color='blue')
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\344896669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data[data.income==1].capital_gain , color='red')
# c:\Users\anime\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\344896669.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
sns.displot(x=data.capital_loss)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# plt.xticks(rotation=90 , ha='left')
plt.figure(figsize=(15,10))
sns.lineplot(x=data[data.income=='<=50K']['hours_per_week'] , y=data[data.income=='<=50K']['hours_per_week']  , color='blue' )
sns.scatterplot(x=data[data.income=='>50K']['hours_per_week']  , y=data[data.income=='>50K']['hours_per_week']  , color='red' )
# Out:
# <Axes: xlabel='hours_per_week', ylabel='hours_per_week'>

# %%
data.native_country.value_counts()
# Out:
# native_country
# United-States                 44689
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# ...

# %%
# data.drop(['hours_per_week'] , axis=1,inplace=True)

# %%
sns.distplot(x=data[data.income==1].hours_per_week , color='red')
sns.distplot(x=data[data.income==0].hours_per_week , color='blue')
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\457868440.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data[data.income==1].hours_per_week , color='red')
# c:\Users\anime\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# C:\Users\anime\AppData\Local\Temp\ipykernel_13004\457868440.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
# data.income.replace('<=50K' , '0' , inplace=True)
# data.income.replace('>50K' , '1' , inplace=True)
# data.income.astype(float)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# sns.lineplot(x=data[data.income==1].fnlwgt,y=data[data.income==1].fnlwgt , color='red')
# sns.scatterplot(x=data[data.income==0].fnlwgt,y=data[data.income==0].fnlwgt , color='blue')

# %%
from sklearn.preprocessing import LabelEncoder
data.workclass = LabelEncoder().fit_transform(data.workclass)
data.education = LabelEncoder().fit_transform(data.education)
data.marital_status = LabelEncoder().fit_transform(data.marital_status)
data.occupation = LabelEncoder().fit_transform(data.occupation)
data.relationship = LabelEncoder().fit_transform(data.relationship)
data.race = LabelEncoder().fit_transform(data.race)
data.gender = LabelEncoder().fit_transform(data.gender)
data.native_country = LabelEncoder().fit_transform(data.native_country)
data.income = LabelEncoder().fit_transform(data.income)

# %%
inputs = data.drop([  'income' , 'fnlwgt'] , axis=1)
output=data.income

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(inputs , output , test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# # Using naive bayes GAUSSIANNB

# %%
from sklearn.naive_bayes import GaussianNB
g=GaussianNB()
g.fit(x_train , y_train)
yp1 = g.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.7952917093142272
# 0.33049403747870526
# 0.6445182724252492
# 0.4369369369369369

# %% [markdown]
# # using SVM

# %%
# from sklearn import svm
# g=svm.SVC(kernel='rbf' , C=1000 , gamma=0.1)
# g.fit(x_train , y_train)
# yp1 = g.predict(x_test)
# from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
# print(accuracy_score(y_test , yp1))
# print(recall_score(y_test , yp1))
# print(precision_score(y_test , yp1))
# print(f1_score(y_test , yp1))

# %% [markdown]
# # using  Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
g=LogisticRegression()
g.fit(x_train , y_train)
yp1 = g.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.8221084953940635
# 0.4505962521294719
# 0.702523240371846
# 0.5490399584846912

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=data.corr() , annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # using KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
g=KNeighborsClassifier(n_neighbors=3)
g.fit(x_train , y_train)
yp1 = g.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.8274309109518936
# 0.6081771720613288
# 0.650865998176846
# 0.6287978863936592

# %% [markdown]
# # Deciscion Tree

# %%
from sklearn.tree import DecisionTreeClassifier
alg=DecisionTreeClassifier(criterion='entropy')
alg.fit(x_train , y_train)
yp1 = alg.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.8221084953940635
# 0.6124361158432708
# 0.6345984112974404
# 0.623320329432163

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
alg=RandomForestClassifier(criterion='entropy')
alg.fit(x_train , y_train)
yp1 = alg.predict(x_test)
from sklearn.metrics import  accuracy_score , precision_score , recall_score , f1_score
print(accuracy_score(y_test , yp1))
print(recall_score(y_test , yp1))
print(precision_score(y_test , yp1))
print(f1_score(y_test , yp1))
# Out:
# 0.8499488229273285
# 0.6243611584327087
# 0.7151219512195122
# 0.6666666666666666
