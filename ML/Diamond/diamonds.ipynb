# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set(style='darkgrid', palette='Dark2')

# %%
data=pd.read_csv('diamonds.csv')
data
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
data.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
data.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
sns.distplot(x=data.price)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=data.carat)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.lineplot(x=data.carat , y=data.price )
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
data
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
sns.barplot(x=data.cut , y=data.price , hue=data.cut)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.barplot(x=data.color , y=data.price , hue=data.color)
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
sns.barplot(x=data.clarity , y=data.price , hue=data.clarity)
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %%
sns.lineplot(x=data.table ,y=data.price)
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %%
sns.lineplot(x=data.x ,y=data.price)
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.lineplot(x=data.y ,y=data.price)
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.lineplot(x=data.z ,y=data.price)
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
data
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
sns.lineplot(x=data.table ,y=data.price , hue=data.clarity)
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %%
data1=data

# %%
from sklearn.preprocessing import LabelEncoder
data1.clarity=LabelEncoder().fit_transform(data.clarity)
data1.cut=LabelEncoder().fit_transform(data.cut)
data1.color=LabelEncoder().fit_transform(data.color)

# %%
data1
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 0       0.23    2      1        3   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    3      1        2   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23    1      1        4   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    3      5        5   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31    1      6        3   63.3   58.0  4.34  4.35  2.75    335
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 53935   0.72    2      0        2   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72    1      0        2   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70    4      0        2   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    3      4        3   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75    2      0        3   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data=data1.corr() , annot=True)
# Out:
# <Axes: >

# %%
inputs = data1.drop(['price','depth' ] , axis=1)
output=data.price

from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(inputs , output , test_size=0.2)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_test = sc.fit_transform(x_test)
x_train = sc.fit_transform(x_train)

# %% [markdown]
# # Using linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
alg=LinearRegression().fit(x_train , y_train)
pred_y=alg.predict(x_test)
print(mean_squared_error(pred_y , y_test))
print(r2_score(pred_y , y_test))
# Out:
# 1907321.1125491553
# 0.8655627586424541

# %% [markdown]
# # [polynomial regression]

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=2)

new_x_train = poly.fit_transform(x_train)
new_x_test=poly.fit_transform(x_test)

reg=LinearRegression()
reg.fit(new_x_train , y_train)
pred_y=reg.predict(new_x_test)
print(mean_squared_error(pred_y , y_test))
print(r2_score(pred_y , y_test))
# Out:
# 1134941.2261642232
# 0.9283340733535742

# %%
from sklearn.ensemble import AdaBoostRegressor

from sklearn.tree import DecisionTreeRegressor
lr = DecisionTreeRegressor(max_depth=3)

alg = AdaBoostRegressor(estimator=lr)
alg.fit(x_train , y_train)
yp=alg.predict(x_test)
print(mean_squared_error(yp , y_test))
print(r2_score(yp , y_test))
# Out:
# 1925243.4880920497
# 0.8651539676403507
