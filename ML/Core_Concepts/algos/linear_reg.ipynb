# %%
class LinearReg:
    def __init__(self):
        self.m=None
        self.b=None
    
    def fit(self , x_train , y_train):
        print('fitting model')
        num=0
        den=0 
        for i in range(x_train.shape[0]):
            num +=( (x_train[i]-x_train.mean()) * (y_train[i]-y_train.mean()))
            den += ((x_train[i]-x_train.mean())**2)
            
        self.m=num/den
        
        self.b = y_train.mean() -  (self.m*x_train.mean())
            
        return self.m,self.b
    
    def predict(self , x_test):
        print('predicted values')
        return  (self.m*x_test) + self.b

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('plc.csv')
data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=data.iloc[:,0].values
y=data.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
lr=LinearReg()
lr.fit(x_train , y_train)
# Out:
# (0.5704348836688591, -1.0138340756536297)

# %%
lr.predict(x_test)
# Out:
# predict
# array([3.33858409, 3.09900144, 2.94498402, 2.67687962, 3.0248449 ,
#        3.00202751, 3.65232327, 3.45837541, 3.49260151, 3.14463623,
#        1.59305334, 2.46581871, 3.41274062, 2.59701874, 2.78526225,
#        2.96209706, 3.13893188, 2.51715785, 3.48689716, 3.15034058,
#        1.75277511, 2.38025348, 3.69225371, 3.90901897, 3.41844497,
#        2.82519269, 2.18630562, 4.29691469, 2.89364488, 3.32147104,
#        2.47722741, 3.60668848, 2.58561004, 2.07792299, 4.15430597,
#        3.60098413, 2.35743609, 2.16919258, 3.12181883, 2.51715785])
