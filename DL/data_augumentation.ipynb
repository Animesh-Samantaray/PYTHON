# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.utils import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img(r'D:\PYTHON\DL\train_img\anim1.jpeg' , target_size=(500,500))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
datagen = ImageDataGenerator(
    rotation_range=40,shear_range=0.2,zoom_range=0.2 , horizontal_flip=True,
    vertical_flip=True,width_shift_range=0.2,
    height_shift_range=0.2
)

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
input_batch=img.reshape(1,500,500,3)

# %%
i=0


for output in datagen.flow(input_batch , batch_size=1 , save_to_dir='train_img'):
    i=i+1
    
    if i==10:
        break
