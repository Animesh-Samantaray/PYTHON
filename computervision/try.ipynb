# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread(r"C:\Users\anime\Pictures\Camera Roll\WIN_20250624_11_10_48_Pro.jpg")

# %%
cv2.imshow('Animesj',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img[::,::,::-1])
# plt.axis('off')

# %%
rgb_img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
gray_img = cv2.cvtColor(rgb_img , cv2.COLOR_RGB2GRAY)
cv2.imshow('Animesh',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(gray_img)
plt.show()

# %%
cap = cv2.VideoCapture(0)
if cap.isOpened():
    ret,frame=cap.read()
    # print(ret)
    # print(frame)
else:
    ret=False

image = cv2.cvtColor(frame ,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title('Animesh')
plt.show()
cap.release()

# %% [markdown]
# # Edge detection

# %%
img = cv2.imread(r"C:\Users\anime\Downloads\doraemon.jpg")
edge_dect = cv2.Canny(img , 100 , 200)
plt.imshow(edge_dect , cmap='gray')
plt.show()

# %%
img = cv2.imread(r"C:\Users\anime\Pictures\Camera Roll\WIN_20250624_11_10_48_Pro.jpg")
plt.imshow(img[::,::,::-1])

# %%
i=cv2.rectangle(img,(420,510) , (840,10),(10,255,67 ),3)
plt.imshow(i[::,::,::-1])

# %%
face = r"C:\Users\anime\Downloads\haarcascade_frontalface_default.xml"
cap = cv2.VideoCapture(0)
ret,frame = cap.read()

while ret:
    ret,frame = cap.read()
    
    if not ret:
        break
     
    model = cv2.CascadeClassifier(face)
    facepoints = model.detectMultiScale(frame)

    for x,y,w,h in facepoints:
        cv2.rectangle(frame , (x,y) , (x+w , y+h) , (0,0,255) , 3)

    cv2.imshow('Animesh',frame)
    if cv2.waitKey(10)==27:
        break

cv2.destroyAllWindows()
cap.release()
