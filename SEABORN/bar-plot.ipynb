# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # hue is used to do color separation based on different values of a column

# %%
dt=sns.load_dataset('penguins')
dt
sns.set(style='whitegrid')
sns.barplot(x=dt.island , y=dt.body_mass_g,hue=dt.sex,saturation=100,alpha=1)
plt.show()
# alpha-->blurness
# palette--->clring
