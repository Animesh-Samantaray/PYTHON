# %%
import matplotlib.pyplot as plt
import  seaborn as sns
import pandas as pd

# %%
data=sns.load_dataset('penguins')
sns.displot(data['flipper_length_mm'],bins=[i+5 for i in range(165 , 226)],kde=True,rug=True,color='r')
